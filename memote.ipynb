# %%
# !pip install memote

# %%
import memote
# !memote report snapshot --filename "megasphaera_sp_MJR8396C.html" -- Megasphaera_sp_MJR8396C.xml
# Out:
# The current solver interface glpk doesn't support setting the optimality tolerance.
# ============================= test session starts ==============================
# platform darwin -- Python 3.11.5, pytest-7.4.3, pluggy-1.3.0
# rootdir: /usr/local/Caskroom/miniconda/base/envs/scriptie/lib/python3.11/site-packages/memote/suite/tests
# plugins: anyio-4.2.0
# collected 146 items / 1 skipped
#
# ../../../../../../usr/local/Caskroom/miniconda/base/envs/scriptie/lib/python3.11/site-packages/memote/suite/tests/test_annotation.py . [  0%]
# .FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF..FF...F..F....F.F.FFFFFFFFFF..         [ 44%]
# ../../../../../../usr/local/Caskroom/miniconda/base/envs/scriptie/lib/python3.11/site-packages/memote/suite/tests/test_basic.py . [ 45%]
# ...F.F...........FFFFF                                                   [ 60%]
# ../../../../../../usr/local/Caskroom/miniconda/base/envs/scriptie/lib/python3.11/site-packages/memote/suite/tests/test_biomass.py . [ 60%]
# ...
